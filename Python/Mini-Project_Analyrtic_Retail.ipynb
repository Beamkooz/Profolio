# %% [markdown]
# **1. Read raw data from google sheet as Dataframe and print some detail of the dataframe**

# %%
#Write your code here:
import pandas as pd
df = pd.read_excel("Raw_Data.xlsx")

# %%
df
# Out:
#           Order ID       Item ID  Gender    Payment Method  \
# 0     3.634920e+13  2.312500e+09  Female     Bank Transfer
# 1     3.634920e+13  2.323194e+09  Female  Cash on Delivery
# 2     3.634920e+13  6.704558e+09    Male  Cash on Delivery
# 3     3.634920e+13  1.566237e+09    Male    Online Banking
# 4     3.634920e+13  2.353090e+09    Male  Cash on Delivery
# ...            ...           ...     ...               ...
# 9382  3.635164e+13  2.303805e+09    Male          e-Wallet
# 9383  3.635164e+13  6.708949e+08    Male          e-Wallet
# 9384  3.635164e+13  1.758139e+09    Male          e-Wallet
# 9385  3.635164e+13  1.936938e+09    Male          e-Wallet
# 9386  3.635164e+13  1.433453e+09    Male          e-Wallet
#
#          Shipping Carrier             Category      Shop ID     Buyer ID  \
# 0          Shopee Express        Home & Living    6062144.0     101134.0
# 1                   Kerry   Stationery & Books  133280183.0  227715943.0
# ...

# %% [markdown]
# **2. Create a dataframe of each category like the following table**
#
# ![Screen Shot 2564-09-03 at 10.09.52.png](data:image/png;base64,...)

# %%
##Write your code here:
q2 = df[["Category","Shop ID","Voucher Subsidy","Rebate Subsidy","Shipping Subsidy"]].sort_values(["Category", "Shop ID"])
q2
# Out:
#          Category      Shop ID  Voucher Subsidy  Rebate Subsidy  \
# 7359  Baby & Toys      73483.0              0.0             0.0
# 8347  Baby & Toys      73483.0              0.0             0.0
# 7722  Baby & Toys      79309.0              0.0             0.0
# 579   Baby & Toys     211634.0              0.0             0.0
# 4744  Baby & Toys     411842.0             54.0             0.0
# ...           ...          ...              ...             ...
# 8573  Women Shoes  189190326.0              0.0             0.0
# 6735  Women Shoes  199943325.0              0.0             0.0
# 3631  Women Shoes  203222018.0              0.0             0.0
# 92    Women Shoes  206083182.0              0.0             0.0
# 3551  Women Shoes  222404116.0              0.0             0.0
#
#       Shipping Subsidy
# 7359               0.0
# 8347               0.0
# 7722               0.0
# 579                0.0
# 4744               0.0
# ...                ...
# 8573               0.0
# ...

# %% [markdown]
# **3. What's the top 10 products that buyers order the most for each category?**
#
# ![Screen Shot 2564-09-03 at 10.13.09.png](data:image/png;base64,...)

# %%
 New = df[["Category","Item ID"]].value_counts().reset_index()
 New
# Out:
#                     Category       Item ID    0
# 0                     Others  6.916943e+09  207
# 1        Fashion Accessories  1.253403e+09  116
# 2     Beauty & Personal Care  4.712654e+09   91
# 3                     Others  6.916943e+09   82
# 4                     Others  6.916943e+09   76
# ...                      ...           ...  ...
# 6726        Gaming & Hobbies  2.003384e+09    1
# 6727        Gaming & Hobbies  1.913705e+09    1
# 6728        Gaming & Hobbies  1.847930e+09    1
# 6729        Gaming & Hobbies  1.755106e+09    1
# 6730             Women Shoes  7.714312e+09    1
#
# [6731 rows x 3 columns]

# %%
New.columns = ["Category", "Item ID", "# of Order"]

# %%
New["Category"].unique()
# Out:
# array(['Others', 'Fashion Accessories', 'Beauty & Personal Care',
#        'Women Clothes', 'Health & Wellness', 'Food & Beverages',
#        'Home Appliances', 'Home & Living', 'Baby & Toys',
#        'Watches & Glasses', 'Men Shoes', 'Motors', 'Mobile & Gadgets',
#        'Women Shoes', 'Stationery & Books', 'Bags', 'Computers & Laptops',
#        'Men Clothes', 'Tickets & Vouchers', 'Gaming & Hobbies', 'Pets',
#        'Home Entertainment', 'Sports & Outdoors', 'Cameras'], dtype=object)

# %%
def Top_Product(a):
  a = New[(New["Category"] == a)].head(10)
  return a

# %% [markdown]
# Answer

# %%
Others =Top_Product("Others")
Others
# Out:
#     Category       Item ID  # of Order
# 0     Others  6.916943e+09         207
# 3     Others  6.916943e+09          82
# 4     Others  6.916943e+09          76
# 10    Others  6.916943e+09          34
# 18    Others  7.016943e+09          22
# 29    Others  7.016943e+09          16
# 55    Others  5.616104e+09           9
# 125   Others  4.021334e+08           5
# 390   Others  4.116775e+09           2
# 397   Others  7.116775e+09           2

# %%
Fashion_Accessories =Top_Product("Fashion Accessories")
Fashion_Accessories
# Out:
#                 Category       Item ID  # of Order
# 1    Fashion Accessories  1.253403e+09         116
# 19   Fashion Accessories  2.777849e+09          18
# 25   Fashion Accessories  1.564005e+09          17
# 37   Fashion Accessories  2.005269e+09          12
# 69   Fashion Accessories  1.350534e+09           8
# 74   Fashion Accessories  5.500224e+09           7
# 100  Fashion Accessories  2.438606e+09           6
# 114  Fashion Accessories  2.069365e+09           5
# 144  Fashion Accessories  5.009122e+09           4
# 185  Fashion Accessories  1.951561e+09           3

# %%
Beauty_Personal_Care = Top_Product("Beauty & Personal Care")
Beauty_Personal_Care
# Out:
#                   Category       Item ID  # of Order
# 2   Beauty & Personal Care  4.712654e+09          91
# 7   Beauty & Personal Care  7.807016e+09          43
# 9   Beauty & Personal Care  7.116528e+09          39
# 21  Beauty & Personal Care  1.857057e+09          18
# 32  Beauty & Personal Care  2.175243e+09          15
# 39  Beauty & Personal Care  6.639023e+08          12
# 49  Beauty & Personal Care  2.100793e+08          10
# 62  Beauty & Personal Care  2.295604e+09           8
# 63  Beauty & Personal Care  2.282937e+09           8
# 73  Beauty & Personal Care  7.716394e+09           7

# %%
Women_Clothes =Top_Product("Women Clothes")
Women_Clothes
# Out:
#           Category       Item ID  # of Order
# 5    Women Clothes  1.183404e+09          54
# 38   Women Clothes  7.001996e+09          12
# 44   Women Clothes  2.281766e+09          11
# 45   Women Clothes  7.116412e+09          11
# 47   Women Clothes  6.611266e+09          11
# 50   Women Clothes  2.222339e+09          10
# 65   Women Clothes  7.916068e+09           8
# 79   Women Clothes  2.332516e+09           7
# 87   Women Clothes  5.708749e+09           6
# 142  Women Clothes  4.203864e+09           4

# %%
Health_Wellness = Top_Product("Health & Wellness")
Health_Wellness
# Out:
#              Category       Item ID  # of Order
# 6   Health & Wellness  2.694866e+09          48
# 8   Health & Wellness  2.322987e+09          42
# 15  Health & Wellness  3.615810e+09          24
# 23  Health & Wellness  1.305463e+09          17
# 26  Health & Wellness  2.236651e+09          16
# 33  Health & Wellness  1.969661e+09          14
# 41  Health & Wellness  8.401377e+08          11
# 46  Health & Wellness  1.568913e+08          11
# 58  Health & Wellness  1.788020e+09           9
# 59  Health & Wellness  1.995199e+09           9

# %%
Food_Beverages =Top_Product("Food & Beverages")
Food_Beverages
# Out:
#              Category       Item ID  # of Order
# 11   Food & Beverages  2.458847e+09          31
# 60   Food & Beverages  1.144359e+09           8
# 61   Food & Beverages  8.663094e+08           8
# 103  Food & Beverages  4.621550e+08           6
# 127  Food & Beverages  2.865016e+09           4
# 130  Food & Beverages  3.304476e+09           4
# 164  Food & Beverages  2.723717e+09           4
# 241  Food & Beverages  1.836501e+09           3
# 248  Food & Beverages  2.873794e+09           3
# 252  Food & Beverages  6.201429e+09           3

# %%
Home_Appliances =Top_Product("Home Appliances")
Home_Appliances
# Out:
#             Category       Item ID  # of Order
# 12   Home Appliances  1.875144e+09          28
# 56   Home Appliances  2.777487e+09           9
# 126  Home Appliances  2.289284e+09           4
# 147  Home Appliances  2.255763e+09           4
# 161  Home Appliances  3.316151e+09           4
# 197  Home Appliances  1.940724e+09           3
# 253  Home Appliances  7.916396e+09           3
# 618  Home Appliances  9.309402e+08           2
# 619  Home Appliances  6.414609e+09           2
# 620  Home Appliances  1.170909e+09           2

# %%
Home_Living =Top_Product("Home & Living")
Home_Living
# Out:
#          Category       Item ID  # of Order
# 13  Home & Living  2.058275e+09          27
# 24  Home & Living  4.101367e+09          17
# 30  Home & Living  2.698620e+09          15
# 31  Home & Living  3.604610e+09          15
# 40  Home & Living  7.400217e+09          12
# 42  Home & Living  1.178076e+09          11
# 43  Home & Living  1.969854e+09          11
# 52  Home & Living  2.577061e+09           9
# 53  Home & Living  7.297591e+08           9
# 75  Home & Living  2.196557e+09           7

# %%
Baby_and_Toys =Top_Product("Baby & Toys")
Baby_and_Toys
# Out:
#         Category       Item ID  # of Order
# 14   Baby & Toys  9.701099e+08          26
# 48   Baby & Toys  4.360310e+08          10
# 67   Baby & Toys  2.808503e+09           8
# 95   Baby & Toys  1.313964e+08           6
# 118  Baby & Toys  1.287706e+09           5
# 156  Baby & Toys  6.005485e+09           4
# 167  Baby & Toys  1.354991e+09           4
# 186  Baby & Toys  2.578600e+09           3
# 188  Baby & Toys  2.523865e+09           3
# 196  Baby & Toys  2.235868e+09           3

# %%
Watches_Glasses =Top_Product("Watches & Glasses")
Watches_Glasses
# Out:
#               Category       Item ID  # of Order
# 16   Watches & Glasses  2.344774e+08          24
# 17   Watches & Glasses  1.488629e+09          22
# 22   Watches & Glasses  1.479527e+09          18
# 54   Watches & Glasses  1.791019e+09           9
# 77   Watches & Glasses  1.906091e+08           7
# 105  Watches & Glasses  2.323516e+09           6
# 115  Watches & Glasses  7.709704e+09           5
# 128  Watches & Glasses  1.564589e+09           4
# 148  Watches & Glasses  4.012249e+09           4
# 275  Watches & Glasses  1.576789e+09           2

# %%
Men_Shoes =Top_Product("Men Shoes")
Men_Shoes
# Out:
#       Category       Item ID  # of Order
# 20   Men Shoes  4.110070e+09          18
# 97   Men Shoes  2.912330e+09           6
# 140  Men Shoes  2.779098e+08           4
# 199  Men Shoes  2.693575e+09           3
# 279  Men Shoes  4.505800e+09           2
# 290  Men Shoes  6.808318e+09           2
# 296  Men Shoes  7.112690e+09           2
# 298  Men Shoes  2.912413e+09           2
# 360  Men Shoes  4.408286e+08           2
# 363  Men Shoes  1.566237e+09           2

# %%
Motors =Top_Product("Motors")
Motors
# Out:
#     Category       Item ID  # of Order
# 27    Motors  8.199269e+08          16
# 83    Motors  1.335998e+09           6
# 102   Motors  2.645578e+09           6
# 117   Motors  1.565730e+09           5
# 119   Motors  5.281514e+08           5
# 139   Motors  2.303427e+09           4
# 145   Motors  1.263110e+09           4
# 159   Motors  1.921205e+09           4
# 221   Motors  6.500634e+09           3
# 240   Motors  2.716448e+09           3

# %%
Mobile_and_Gadgets =Top_Product("Mobile & Gadgets")
Mobile_and_Gadgets
# Out:
#              Category       Item ID  # of Order
# 28   Mobile & Gadgets  4.405292e+09          16
# 34   Mobile & Gadgets  2.601401e+09          14
# 70   Mobile & Gadgets  7.308957e+09           7
# 84   Mobile & Gadgets  1.238886e+09           6
# 92   Mobile & Gadgets  6.106188e+09           6
# 129  Mobile & Gadgets  2.312927e+09           4
# 132  Mobile & Gadgets  2.775498e+09           4
# 166  Mobile & Gadgets  2.690525e+08           4
# 174  Mobile & Gadgets  2.299457e+09           3
# 178  Mobile & Gadgets  1.620383e+09           3

# %%
Women_Shoes =Top_Product("Women Shoes")
Women_Shoes
# Out:
#         Category       Item ID  # of Order
# 35   Women Shoes  1.354192e+09          14
# 110  Women Shoes  2.854925e+09           5
# 121  Women Shoes  5.615212e+09           5
# 124  Women Shoes  2.040723e+09           5
# 137  Women Shoes  2.359578e+09           4
# 165  Women Shoes  1.328697e+08           4
# 220  Women Shoes  3.609653e+09           3
# 242  Women Shoes  2.260981e+09           3
# 607  Women Shoes  3.603571e+09           2
# 625  Women Shoes  2.491388e+09           2

# %%
Stationery_Books = Top_Product("Stationery & Books")
Stationery_Books
# Out:
#                Category       Item ID  # of Order
# 36   Stationery & Books  2.339621e+09          13
# 101  Stationery & Books  1.098762e+09           6
# 116  Stationery & Books  3.307979e+09           5
# 190  Stationery & Books  1.369649e+09           3
# 219  Stationery & Books  4.715913e+09           3
# 274  Stationery & Books  5.417576e+09           3
# 501  Stationery & Books  2.216408e+09           2
# 508  Stationery & Books  1.920773e+09           2
# 511  Stationery & Books  1.810489e+09           2
# 513  Stationery & Books  1.683048e+09           2

# %%
Bags =Top_Product("Bags")
Bags
# Out:
#     Category       Item ID  # of Order
# 51      Bags  2.578197e+09           9
# 66      Bags  2.087825e+09           8
# 71      Bags  4.816819e+09           7
# 72      Bags  2.346248e+09           7
# 106     Bags  1.778320e+09           5
# 107     Bags  5.206170e+09           5
# 133     Bags  1.506293e+09           4
# 163     Bags  2.319934e+09           4
# 180     Bags  1.474991e+09           3
# 192     Bags  1.448917e+09           3

# %%
Computers_and_Laptops =Top_Product("Computers & Laptops")
Computers_and_Laptops
# Out:
#                  Category       Item ID  # of Order
# 57    Computers & Laptops  2.311755e+09           9
# 112   Computers & Laptops  1.458491e+09           5
# 477   Computers & Laptops  1.153662e+09           2
# 478   Computers & Laptops  1.459264e+09           2
# 488   Computers & Laptops  2.760692e+09           2
# 489   Computers & Laptops  2.839856e+09           2
# 4084  Computers & Laptops  4.808336e+08           1
# 4085  Computers & Laptops  3.731634e+08           1
# 4086  Computers & Laptops  2.723022e+08           1
# 4087  Computers & Laptops  1.715783e+08           1

# %%
Men_Clothes =Top_Product("Men Clothes")
Men_Clothes
# Out:
#         Category       Item ID  # of Order
# 64   Men Clothes  1.133403e+09           8
# 85   Men Clothes  2.256267e+09           6
# 151  Men Clothes  9.230435e+08           4
# 177  Men Clothes  2.848174e+09           3
# 179  Men Clothes  2.307533e+09           3
# 310  Men Clothes  5.159825e+08           2
# 313  Men Clothes  7.308082e+08           2
# 315  Men Clothes  9.514998e+08           2
# 317  Men Clothes  1.243124e+09           2
# 343  Men Clothes  1.432056e+09           2

# %%
Tickets_and_Vouchers =Top_Product("Tickets & Vouchers")
Tickets_and_Vouchers
# Out:
#                 Category       Item ID  # of Order
# 68    Tickets & Vouchers  1.562053e+09           8
# 82    Tickets & Vouchers  1.545523e+09           6
# 150   Tickets & Vouchers  2.873735e+09           4
# 226   Tickets & Vouchers  1.562049e+09           3
# 282   Tickets & Vouchers  6.416421e+09           2
# 291   Tickets & Vouchers  1.562051e+09           2
# 295   Tickets & Vouchers  7.517853e+09           2
# 297   Tickets & Vouchers  6.517729e+09           2
# 3269  Tickets & Vouchers  2.874447e+07           1
# 3290  Tickets & Vouchers  1.248397e+08           1

# %%
Gaming_and_Hobbies =Top_Product("Gaming & Hobbies")
Gaming_and_Hobbies
# Out:
#               Category       Item ID  # of Order
# 80    Gaming & Hobbies  9.030478e+08           7
# 424   Gaming & Hobbies  6.214948e+09           2
# 6681  Gaming & Hobbies  7.816998e+09           1
# 6682  Gaming & Hobbies  7.814623e+09           1
# 6683  Gaming & Hobbies  7.212551e+09           1
# 6684  Gaming & Hobbies  7.111010e+09           1
# 6685  Gaming & Hobbies  6.690540e+08           1
# 6686  Gaming & Hobbies  2.616141e+08           1
# 6706  Gaming & Hobbies  8.046942e+08           1
# 6707  Gaming & Hobbies  1.084412e+09           1

# %%
Pets =Top_Product("Pets")
Pets
# Out:
#     Category       Item ID  # of Order
# 91      Pets  1.908292e+09           6
# 111     Pets  1.237935e+09           5
# 138     Pets  1.398644e+09           4
# 212     Pets  6.816720e+09           3
# 251     Pets  1.956957e+09           3
# 264     Pets  1.693620e+09           3
# 273     Pets  6.721556e+08           3
# 392     Pets  6.287703e+08           2
# 394     Pets  3.236067e+08           2
# 415     Pets  1.133531e+09           2

# %%
Home_Entertainment =Top_Product("Home Entertainment")
Home_Entertainment
# Out:
#                Category       Item ID  # of Order
# 122  Home Entertainment  7.904223e+09           5
# 136  Home Entertainment  2.331198e+09           4
# 168  Home Entertainment  8.266237e+08           4
# 211  Home Entertainment  3.212053e+09           3
# 222  Home Entertainment  2.608671e+09           3
# 257  Home Entertainment  2.380789e+09           3
# 260  Home Entertainment  2.374397e+09           3
# 305  Home Entertainment  7.101697e+09           2
# 308  Home Entertainment  7.613711e+09           2
# 331  Home Entertainment  2.385028e+09           2

# %%
Sports_and_Outdoors =Top_Product("Sports & Outdoors")
Sports_and_Outdoors
# Out:
#               Category       Item ID  # of Order
# 134  Sports & Outdoors  3.307573e+09           4
# 152  Sports & Outdoors  5.774096e+08           4
# 157  Sports & Outdoors  2.393618e+09           4
# 198  Sports & Outdoors  2.322299e+09           3
# 558  Sports & Outdoors  2.100275e+09           2
# 564  Sports & Outdoors  1.872209e+09           2
# 566  Sports & Outdoors  1.597467e+09           2
# 568  Sports & Outdoors  1.392579e+09           2
# 571  Sports & Outdoors  9.589011e+08           2
# 575  Sports & Outdoors  4.154576e+08           2

# %%
Cameras =Top_Product("Cameras")
Cameras
# Out:
#     Category       Item ID  # of Order
# 158  Cameras  7.669200e+08           4
# 400  Cameras  3.134653e+08           2
# 402  Cameras  1.005952e+09           2
# 406  Cameras  1.818331e+09           2
# 408  Cameras  2.272830e+09           2
# 409  Cameras  2.312469e+09           2
# 411  Cameras  2.448831e+09           2
# 412  Cameras  2.596641e+09           2
# 471  Cameras  3.307260e+09           2
# 474  Cameras  7.211575e+09           2

# %%
#Write

# %% [markdown]
# **4. Plot bar chart to show Revenue by category**

# %%
revenue_sum = df.groupby("Category")["Revenue"].sum()
revenue_sum
# Out:
# Category
# Baby & Toys               166464.0
# Bags                      246107.0
# Beauty & Personal Care    334984.0
# Cameras                   142554.0
# Computers & Laptops       199423.0
# Fashion Accessories       540747.0
# Food & Beverages           42539.0
# Gaming & Hobbies           58466.0
# Health & Wellness         394196.0
# Home & Living             259927.0
# Home Appliances           338834.0
# Home Entertainment        171105.0
# Men Clothes                40726.0
# Men Shoes                  26772.0
# Mobile & Gadgets          463584.0
# Motors                    111497.0
# Others                     18564.0
# Pets                       43541.0
# Sports & Outdoors          71215.0
# Stationery & Books         44393.0
# Tickets & Vouchers         19377.0
# Watches & Glasses         110141.0
# Women Clothes             134028.0
# Women Shoes                25160.0
# Name: Revenue, dtype: float64

# %%
revenue_sum.plot(kind='bar')
